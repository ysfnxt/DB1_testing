# %%
import pandas as pd

# %%
df1 = pd.read_csv("1_db_email_and_phone.csv", low_memory=False)

# %%
df2 = pd.read_csv("2file2_ONLY_personal_emails.csv")

# %%
df1
# Out:
#                       name                                              email
# 0           heynel axelevi                       ['heynel_axelevi@yahoo.com']  \
# 1            arran gillies  ['narra1985@hotmail.com', 'arran.gillies@silix...
# 2             don gennrich  ['dongennrich@gmail.com', 'dgennrich@packaging...
# 3                kay patel  ['patelk@parliament.uk', 'kay_patel@hotmail.com']
# 4         brittany couture                         ['run5soccer@hotmail.com']
# ...                    ...                                                ...
# 16250747   caroline alcock  ['carolinealcock@yahoo.co.uk', 'calcock@ksmmed...
# 16250748         jeff levy                        ['jeff@bravomessenger.com']
# 16250749      naomi kinsey  ['naomi.kinsey9410@gmail.com', 'naomikinsey941...
# 16250750   darlene treston                        ['dtreston@trestonlaw.com']
# 16250751     patricia eddy  ['patriciaanneddy@yahoo.com', 'celestouille@ao...
#
# ...

# %%
df2
# Out:
#                     name                       email phone_numbers
# 0        leanne crockett         'llbjork@yahoo.com'            []  \
# 1       linda mcclanahan     'lindamc29@hotmail.com'            []
# 2         michael piazza       'piazzadds@gmail.com'            []
# 3            lily graves    'lilygraves21@yahoo.com'            []
# 4            travis dahl       'travdahl1@gmail.com'            []
# ...                  ...                         ...           ...
# 643324     randy krueger   'rckrueger@bellsouth.net'            []
# 643325       surya pappu     'surya_pappu@yahoo.com'            []
# 643326  melody haithcock   'dynamicmelody@lycos.com'            []
# 643327     alicia aquino       'sisha_1@hotmail.com'            []
# 643328  marianne oconnor        'djomro@hotmail.com'            []
#
#                                       linkedinurl
# 0        linkedin.com/in/leanne-crockett-52327622
# 1       linkedin.com/in/linda-mcclanahan-0b090b14
# ...

# %%
df2['linkedinurl'].isin(df1['linkedinurl'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 643324    False
# 643325    False
# 643326    False
# 643327    False
# 643328    False
# Name: linkedinurl, Length: 643329, dtype: bool

# %%
common_values_1 = set(df1['linkedinurl'].values).intersection(set(df2['linkedinurl'].values))

# %%
common_values_1
# Out:
# set()
